# %% [markdown]
# <a href="https://colab.research.google.com/github/DanilChernov2006/Homework3/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D1%8B%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2

# %%
import numpy as np
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

output_notebook()

p = figure(width = 800, height = 400)

p.line(np.arange(len(wind_speed)), wind_speed, line_width = 2)
p.line(np.arange(len(wind_speed)), forecast, line_width = 2, color = 'green')

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-79ccfffd3337> in <cell line: 0>()
#       7 p = figure(width = 800, height = 400)
#       8
# ----> 9 p.line(np.arange(len(wind_speed)), wind_speed, line_width = 2)
#      10 p.line(np.arange(len(wind_speed)), forecast, line_width = 2, color = 'green')
#      11
#
# NameError: name 'wind_speed' is not defined
